# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model = "gemma-4-31b-it")

response = llm.invoke("How many moons does jupiter have?")

print(response.text)
# Out:
# Jupiter has **95 officially recognized moons**.
#
# This number often changes as astronomers discover new, smaller moons orbiting the planet. The most famous of these are the four large **Galilean moons**: Io, Europa, Ganymede, and Callisto.

# %%
print(response.content)
# Out:
# [{'type': 'thinking', 'thinking': '*   Question: "How many moons does jupiter have?"\n    *   Subject: Jupiter\'s moons.\n\n    *   Jupiter is known for having a vast number of moons.\n    *   The number often changes as new, small moons are discovered.\n    *   *Historical context:* It used to be 67, then 79, then 80, then 95.\n    *   *Current official count (IAU/NASA):* The most widely accepted recent number is 95.\n\n    *   *Direct Answer:* Jupiter has 95 officially recognized moons.\n    *   *Context/Nuance:* Mention that this number changes as astronomers discover more small objects.\n    *   *Key Examples:* Mention the Galilean moons (Io, Europa, Ganymede, Callisto) because they are the most significant.\n\n    *   "Jupiter has **95 officially recognized moons**."\n    *   "This number often changes as astronomers discover new, smaller moons orbiting the planet."\n    *   "The most famous are the four large **Galilean moons**: Io, Europa, Ganymede, and Callisto."'}, {'type': 'text', 'text': 'Jupiter has **95 officially recognized moons**.\n\nThis number often changes as astronomers discover new, smaller moons orbiting the planet. The most famous of these are the four large **Galilean moons**: Io, Europa, Ganymede, and Callisto.'}]

# %%
response = llm.invoke(
    [
        ["system","You are a assistant, and answer the query by providing the history of the query."],
        ["human","How many moons does jupiter have?"]
    ]
)

# %%
print(response.text)
# Out:
# As of 2023, Jupiter is recognized as having **95 moons**. However, the number of known moons has changed significantly over time as our technology and observation methods have improved.
#
# Here is the history of how we discovered Jupiter's moons:
#
# ### 1. The Galilean Era (1610)
# For most of human history, Jupiter appeared to have no moons. This changed in 1610 when **Galileo Galilei** pointed his newly improved telescope at the planet. He discovered the four largest moons—**Io, Europa, Ganymede, and Callisto**. These are now known as the "Galilean moons." This was a revolutionary discovery because it proved that not everything in the universe revolved around the Earth.
#
# ### 2. The Gradual Discovery Phase (1892–1970s)
# For nearly 300 years, it was believed that only four moons existed. In 1892, astronomers discovered **Amalthea**, the fifth moon. Over the next several decades, a few more small moons were spotted, but the count remained low because the remaining moons were too small and dim to be seen with ground-based telescopes.
#
# ### 3. The Space Age and Voyager (1979–1990s)
# The discovery rate accelerated with the launch of space probes. In 1979, **Voyager 1** flew past Jupiter and discovered several new moons, including Thebe and Adrastea. During this era, astronomers began to realize that Jupiter had a large population of "irregular moons"—small, captured asteroids that orbit the planet in distant, tilted, or retrograde paths.
#
# ### 4. The Modern Surge (2000s–Present)
# In the last two decades, the number of known moons has skyrocketed due to the use of powerful digital imaging and automated survey telescopes. Astronomers, led by figures like Scott S. Sheppard, began finding dozens of tiny moons (some only 1–3 kilometers wide).
#
# *   **2018:** The count jumped significantly as several new small moons were confirmed.
# *   **2023:** A team of astronomers announced the discovery of 12 additional moons, bringing the official total recognized by the International Astronomical Union (IAU) to **95**.
#
# Because many of these moons are very small and difficult to track, the number continues to fluctuate as new ones are discovered and others are confirmed or reclassified.
